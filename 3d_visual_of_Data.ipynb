# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("canada_per_capita_income.csv")

# %%
df
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
X=df["year"]

# %%
y=df["per capita income (US$)"]

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
model.fit(X.to_frame(),y) # training the model
# Out:
# LinearRegression()

# %%
predicted=model.predict([[2014]])
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
predicted
# Out:
# array([36317.90364308])

# %%
x=7+np.random.rand(100,1)-2.8
y=7+np.random.rand(100,1)-2.8
z=x**2+y**2+0.2*x+0.2*y+0.1*x*y+2+np.random.randn(100,1)

data=pd.DataFrame({"x":x.flatten(),"y":y.flatten(),"z":z.flatten()})

# %%
df=data
fig=px.scatter_3d(df,x='x',y='y',z='z')
fig.update_layout(width=400,height=400)
fig.show()
# Out:
# <div>                            <div id="a4029734-73f3-4f00-bb16-dd5484a4ef17" class="plotly-graph-div" style="height:400px; width:400px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4029734-73f3-4f00-bb16-dd5484a4ef17")) {                    Plotly.newPlot(                        "a4029734-73f3-4f00-bb16-dd5484a4ef17",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ez=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[4.629864718463048,5.0003611028456,4.970949075351806,5.1804944614909125,4.413689723726675,5.041082748006805,4.478352605824624,4.343823518505507,4.2900947634710755,4.400196760737789,4.973028685832617,5.1068993260037026,5.1959704279
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(data.drop("z",axis=1),z)
# Out:
# LinearRegression()

# %%
x_input=np.linspace(x.min(),x.max(),10)
y_input=np.linspace(y.min(),y.max(),10)

# %%
x_input
# Out:
# array([4.22009819, 4.32881695, 4.43753571, 4.54625447, 4.65497323,
#        4.76369198, 4.87241074, 4.9811295 , 5.08984826, 5.19856702])

# %%
xGrid, yGrid = np.meshgrid(x_input, y_input)
final = np.vstack((xGrid, yGrid)).T

# %%
yGrid.shape
# Out:
# (10, 10)

# %%
final.shape
# Out:
# (10, 20)

# %%
z_final = lr.predict(final).reshape(10,10)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning:
#
# X does not have valid feature names, but LinearRegression was fitted with feature names
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[162], line 1
# ----> 1 z_final = lr.predict(final).reshape(10,10)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_base.py:306, in LinearModel.predict(self, X)
#     292 def predict(self, X):
#     293     """
#     294     Predict using the linear model.
#     295
#    (...)
#     304         Returns predicted values.
#     305     """
# --> 306     return self._decision_function(X)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_base.py:285, in LinearModel._decision_function(self, X)
#     282 def _decision_function(self, X):
#     283     check_is_fitted(self)
# ...

# %%
import plotly.graph_objects as go

fig =px.scatter_3d(df,x='x',y='y',z='z')

fig.add_trace(go.Surface(x = x_input, y = y_input, z =z_final ))

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[176], line 5
#       1 import plotly.graph_objects as go
#       3 fig =px.scatter_3d(df,x='x',y='y',z='z')
# ----> 5 fig.add_trace(go.Surface(x = x_input, y = y_input, z =z_final ))
#       7 fig.show()
#
# NameError: name 'z_final' is not defined

# %%
stu=pd.read_csv("Student_Performance.csv")

# %%
stu.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
df=stu
fig=px.scatter_3d(df,x='Previous Scores',y='Sample Question Papers Practiced',z='Performance Index',color="Sleep Hours")
fig.update_layout(width=1200,height=800)
fig.show()
